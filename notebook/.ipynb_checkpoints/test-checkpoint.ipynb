# %% [markdown]
# ### Import libraries

# %%
library(ggplot2)
library(scales)
library(gtable)
library(grid)
library(argparse)
options(repr.plot.width = 24, repr.plot.height = 12)

# %%
df = read.table("/home/lknq/GitHub/forge/notebook/analysis.txt", header = T, sep = "\t")
# head(df, 2)
print(df)
# Out:
#      Chr    Start      End  Exome           Name Hom Het Total    Y
# 1  chr14 88401213 88401213     17      c.1921A>G 530  73   603 1500
# 2  chr14 88401219 88401219     17      c.1915C>T   0   1     1   10
# 3  chr14 88401222 88401222     17      c.1912G>A   0   1     1  300
# 4  chr14 88406259 88406259     16      c.1901T>C   0   4     4   10
# 5  chr14 88406315 88406315     16      c.1845T.A   0   1     1  300
# 6  chr14 88407757 88407757     15      c.1816A>T   0   1     1   10
# 7  chr14 88407795 88407795     15      c.1778G>C   0   1     1  300
# 8  chr14 88407875 88407875     15      c.1698A>T 530  72   602 1500
# 9  chr14 88407888 88407888     15      c.1685T>C  35 217   252  800
# 10 chr14 88411947 88411947     14      c.1620A>G 530  73   603 1500
# 11 chr14 88411951 88411951     14      c.1616T>C   0   1     1   10
# 12 chr14 88411975 88411975     14      c.1592G>A   0   6     6  300
# 13 chr14 88411994 88411994     14      c.1573G>A   0   9     9  550
# 14 chr14 88414211 88414211     13      c.1350C>T  35 214   249 1000
# 15 chr14 88416225 88416225     12      c.1302C>T   2  44    46  100
# 16 chr14 88416247 88416247     12      c.1280A>G   0   1     1   30
# 17 chr14 88417028 88417028     11      c.1226C>T   0   1     1   40
# 18 chr14 88417082 88417082     11      c.1172A>G   0   1     1   70
# 19 chr14 88429765 88429768     10 c.1121_1124del   0   1     1   20
# 20 chr14 88431898 88431898      9       c.984G>A 174 300   474  350
# 21 chr14 88431969 88431969      9       c.913A>G   8  70    78  200
# 22 chr14 88442712 88442712      7       c.742G>A   0   2     2   10
# 23 chr14 88448563 88448563      6       c.607G>A   0   1     1   30
# 24 chr14 88448571 88448571      6       c.599C>A   0   2     2   40
# 25 chr14 88450770 88450770      5       c.550C>T   0   1     1   70
# 26 chr14 88450836 88450836      5       c.484G>A   0   6     6   20
# 27 chr14 88452945 88452945      4       c.330C>T   0   2     2   50
# 28 chr14 88454535 88454535      3       c.281C>T   0   1     1   10
# 29 chr14 88459373 88459373      1       c.136G>T   0   1     1   30
# 30 chr14 88459434 88459434      1        c.75C>A   0   1     1   40
# 31 chr14 88459448 88459448      1        c.61G>C   0   2     2   70
# 32 chr14 88459467 88459467      1        c.42G>C   0   2     2   20
# 33 chr14 88459475 88459475      1        c.34C>T   0   2     2   50
# 34 chr14 88459481 88459481      1        c.28T>C   1  19    20  100
# 35 chr14 88459576 88459576 Intron       c.-68C>T   0   1     1   10
# 36 chr14 88459795 88459795 Intron      c.-287G>A   2  77    79  150

# %%
maxPOS=88460009
minPOS=88401213

chart = ggplot(
    data=df, 
    aes(x=Start, y=Y)
)

chart = chart + ylab("Coverage") + xlab("mRNA GALC")
chart = chart + scale_x_continuous(labels=comma, breaks = scales::pretty_breaks(n=5), limits=c(minPOS, maxPOS))
chart = chart + scale_y_continuous(limits=c(0, 2000))
df$point_size <- scales::rescale(
            46 * (df$Total^2) + 2,
            to = c(8, 18)
        )

chart = chart + geom_point(
            pch=21, 
            color="#8d8d8d", 
            fill="#8d8d8d", 
            size = df$point_size,
            alpha = 0.9,
        ) + scale_size_identity()

chart = chart + geom_text(
    aes(label = round(Total, 1)),
    color = "white",
    # size = 3
)

chart = chart + geom_text(
    aes(label = Name),
    vjust = -1,
    size = 4,
    angle = 90
)

chart = chart + theme_classic()

chart = chart + theme(
    axis.line.y = element_blank(),
    axis.text.y = element_blank(),
    axis.ticks.y = element_blank(),
    axis.title.y = element_blank(),
    
    axis.text.x = element_text(
        size = 10,
        angle = 45, 
        hjust = 1
    ),
    axis.title.x = element_text(
        size = 15,
        margin = margin(t = 15, b = 15)
    ),
)

chart
# Out:
# plot without title

# %%
ggsave(
    plot = chart, 
    file=file.path("/home/lknq/GitHub/forge/notebook", paste0("Krabe.pdf")), 
    width=24, 
    height=12
)

# %%
print(warnings())
