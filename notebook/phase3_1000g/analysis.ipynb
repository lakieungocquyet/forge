# %%
phase3_1000g_release_samples=read.table(file = "/home/lknq/GitHub/forge/notebook/phase3_1000g/igsr-1000 genomes phase 3 release-samples.tsv", header = T, sep = "\t")
head(phase3_1000g_release_samples, 1)
# Out:
#   Sample.name Sex Biosample.ID Population.code Population.name
# 1 HG00096     M   SAME123268   GBR             British
#   Superpopulation.code Superpopulation.name Population.elastic.ID
# 1 EUR                  European Ancestry    GBR
#   Data.collections
# 1 1000 Genomes on GRCh38,1000 Genomes 30x on GRCh38,Human Genome Structural Variation Consortium, Phase 2,Human Genome Structural Variation Consortium, Phase 3,1KG_ONT_VIENNA,MAGE RNA-seq,1000 Genomes phase 3 release,1000 Genomes phase 1 release,Geuvadis
